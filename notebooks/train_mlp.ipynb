# %%
from pathlib import Path
import numpy as np
import tensorflow as tf

OUTDIR = Path("output")
OUTDIR.mkdir(parents=True, exist_ok=True)
BATCH_SIZE=256
EPOCHS=30

# %%
EXP = Path("/home/avila/github/panspace-paper")

path_train_embeddings = "experiments-paper/6mer/07_25_2024-autoencoder/cross-validation/mean_squared_error-relu-relu-5-fold/faiss-embeddings/embeddings.npy"
path_test_embeddings = "experiments-paper/6mer/07_25_2024-autoencoder/cross-validation/mean_squared_error-relu-relu-5-fold/test/embeddings.npy" 
path_train_labels = "experiments-paper/6mer/07_25_2024-autoencoder/cross-validation/train_5-fold.txt" 
path_test_labels = "experiments-paper/6mer/07_25_2024-autoencoder/cross-validation/test_5-fold.txt" 
outdir = "experiments-paper/6mer/07_25_2024-autoencoder/cross-validation/mean_squared_error-relu-relu-5-fold/confident-learning"

# %%
# path_train_embeddings = ""
X_train = np.load(EXP.joinpath(path_train_embeddings)) 

# path_train_labels = ""
labels_train = []
with open(EXP.joinpath(path_train_labels)) as fp:
    for line in fp.readlines():
        label = line.strip().split("\t")[-1]
        labels_train.append(label)

# %%
# path_test_labels = ""
labels_test = []
with open(EXP.joinpath(path_test_labels)) as fp:
    for line in fp.readlines():
        label = line.strip().split("\t")[-1]
        labels_test.append(label)

# %%
unique_labels = list(set(labels_train).union(labels_test))
unique_labels.sort()
dict_labels = {label: idx for idx, label in enumerate(unique_labels)}

# %%
y_train = np.array([dict_labels[l] for l in labels_train])

# %%
# Model parameters
num_classes = len(unique_labels)
input_shape = (128,)

model = tf.keras.Sequential(
    [
        tf.keras.layers.Input(shape=input_shape),
        tf.keras.layers.Dense(64, activation="relu"),
        tf.keras.layers.Dense(32, activation="relu"),
        tf.keras.layers.Dense(num_classes, activation="softmax"),
    ]
)

model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    metrics=[
        tf.keras.metrics.SparseCategoricalAccuracy(name="acc"),
    ],
)

Path(f"{OUTDIR}/checkpoints").mkdir(exist_ok=True, parents=True)
cb_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath=f'{OUTDIR}/checkpoints/weights-mlp.keras',
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    verbose=1
)

# stop training if
cb_earlystop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    mode='min',
    min_delta=0.001,
    patience=20,
    verbose=1
)
# save history of training
cb_csvlogger = tf.keras.callbacks.CSVLogger(
    filename=f'{OUTDIR}/training_log.csv',
    separator='\t',
    append=False
)

# # save time by epoch
# cb_csvtime = CSVTimeHistory(
#     filename=f'{OUTDIR}/time_log.csv',
#     separator='\t',
#     append=False
# )

callbacks = [
    cb_checkpoint,
    cb_earlystop,
    cb_csvlogger,
    # cb_csvtime,
]

model.fit(
    X_train,
    y_train,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_split=0.2,
    callbacks=callbacks,
)
# Out:
# Epoch 1/30
# 1609/1645 [============================>.] - ETA: 0s - loss: 1.1984 - acc: 0.7787
# Epoch 1: val_loss improved from inf to 0.50825, saving model to output/checkpoints/weights-mlp.keras
# 1645/1645 [==============================] - 3s 1ms/step - loss: 1.1837 - acc: 0.7813 - val_loss: 0.5083 - val_acc: 0.9038
# Epoch 2/30
# 1642/1645 [============================>.] - ETA: 0s - loss: 0.4144 - acc: 0.9225
# Epoch 2: val_loss improved from 0.50825 to 0.36364, saving model to output/checkpoints/weights-mlp.keras
# 1645/1645 [==============================] - 2s 1ms/step - loss: 0.4145 - acc: 0.9225 - val_loss: 0.3636 - val_acc: 0.9385
# Epoch 3/30
# 1643/1645 [============================>.] - ETA: 0s - loss: 0.3126 - acc: 0.9417
# Epoch 3: val_loss improved from 0.36364 to 0.31380, saving model to output/checkpoints/weights-mlp.keras
# 1645/1645 [==============================] - 2s 1ms/step - loss: 0.3125 - acc: 0.9418 - val_loss: 0.3138 - val_acc: 0.9460
# Epoch 4/30
# 1633/1645 [============================>.] - ETA: 0s - loss: 0.2657 - acc: 0.9478
# Epoch 4: val_loss improved from 0.31380 to 0.28152, saving model to output/checkpoints/weights-mlp.keras
# 1645/1645 [==============================] - 2s 1ms/step - loss: 0.2655 - acc: 0.9478 - val_loss: 0.2815 - val_acc: 0.9508
# Epoch 5/30
# 1624/1645 [============================>.] - ETA: 0s - loss: 0.2358 - acc: 0.9518
# Epoch 5: val_loss improved from 0.28152 to 0.26539, saving model to output/checkpoints/weights-mlp.keras
# 1645/1645 [==============================] - 2s 1ms/step - loss: 0.2359 - acc: 0.9518 - val_loss: 0.2654 - val_acc: 0.9544
# Epoch 6/30
# 1638/1645 [============================>.] - ETA: 0s - loss: 0.2144 - acc: 0.9549
# Epoch 6: val_loss improved from 0.26539 to 0.25250, saving model to output/checkpoints/weights-mlp.keras
# 1645/1645 [==============================] - 2s 1ms/step - loss: 0.2143 - acc: 0.9550 - val_loss: 0.2525 - val_acc: 0.9553
# Epoch 7/30
# 1635/1645 [============================>.] - ETA: 0s - loss: 0.1981 - acc: 0.9576
# Epoch 7: val_loss improved from 0.25250 to 0.24390, saving model to output/checkpoints/weights-mlp.keras
# 1645/1645 [==============================] - 2s 1ms/step - loss: 0.1983 - acc: 0.9576 - val_loss: 0.2439 - val_acc: 0.9592
# Epoch 8/30
# 1631/1645 [============================>.] - ETA: 0s - loss: 0.1862 - acc: 0.9593
# Epoch 8: val_loss improved from 0.24390 to 0.24059, saving model to output/checkpoints/weights-mlp.keras
# 1645/1645 [==============================] - 2s 1ms/step - loss: 0.1861 - acc: 0.9593 - val_loss: 0.2406 - val_acc: 0.9593
# Epoch 9/30
# 1621/1645 [============================>.] - ETA: 0s - loss: 0.1771 - acc: 0.9604
# Epoch 9: val_loss improved from 0.24059 to 0.23772, saving model to output/checkpoints/weights-mlp.keras
# 1645/1645 [==============================] - 2s 1ms/step - loss: 0.1770 - acc: 0.9604 - val_loss: 0.2377 - val_acc: 0.9603
# Epoch 10/30
# 1629/1645 [============================>.] - ETA: 0s - loss: 0.1695 - acc: 0.9616
# Epoch 10: val_loss improved from 0.23772 to 0.23509, saving model to output/checkpoints/weights-mlp.keras
# 1645/1645 [==============================] - 2s 1ms/step - loss: 0.1694 - acc: 0.9616 - val_loss: 0.2351 - val_acc: 0.9613
# Epoch 11/30
# 1634/1645 [============================>.] - ETA: 0s - loss: 0.1632 - acc: 0.9625
# Epoch 11: val_loss improved from 0.23509 to 0.23241, saving model to output/checkpoints/weights-mlp.keras
# 1645/1645 [==============================] - 2s 1ms/step - loss: 0.1633 - acc: 0.9625 - val_loss: 0.2324 - val_acc: 0.9622
# Epoch 12/30
# 1624/1645 [============================>.] - ETA: 0s - loss: 0.1577 - acc: 0.9633
# Epoch 12: val_loss improved from 0.23241 to 0.23033, saving model to output/checkpoints/weights-mlp.keras
# 1645/1645 [==============================] - 2s 1ms/step - loss: 0.1577 - acc: 0.9633 - val_loss: 0.2303 - val_acc: 0.9630
# Epoch 13/30
# 1640/1645 [============================>.] - ETA: 0s - loss: 0.1529 - acc: 0.9640
# Epoch 13: val_loss improved from 0.23033 to 0.22849, saving model to output/checkpoints/weights-mlp.keras
# 1645/1645 [==============================] - 2s 1ms/step - loss: 0.1529 - acc: 0.9640 - val_loss: 0.2285 - val_acc: 0.9633
# Epoch 14/30
# 1627/1645 [============================>.] - ETA: 0s - loss: 0.1485 - acc: 0.9648
# Epoch 14: val_loss improved from 0.22849 to 0.22607, saving model to output/checkpoints/weights-mlp.keras
# 1645/1645 [==============================] - 2s 1ms/step - loss: 0.1483 - acc: 0.9648 - val_loss: 0.2261 - val_acc: 0.9642
# Epoch 15/30
# 1630/1645 [============================>.] - ETA: 0s - loss: 0.1444 - acc: 0.9654
# Epoch 15: val_loss improved from 0.22607 to 0.22073, saving model to output/checkpoints/weights-mlp.keras
# 1645/1645 [==============================] - 2s 1ms/step - loss: 0.1444 - acc: 0.9654 - val_loss: 0.2207 - val_acc: 0.9639
# Epoch 16/30
# 1634/1645 [============================>.] - ETA: 0s - loss: 0.1408 - acc: 0.9659
# Epoch 16: val_loss did not improve from 0.22073
# 1645/1645 [==============================] - 2s 1ms/step - loss: 0.1407 - acc: 0.9659 - val_loss: 0.2209 - val_acc: 0.9645
# Epoch 17/30
# 1639/1645 [============================>.] - ETA: 0s - loss: 0.1369 - acc: 0.9665
# Epoch 17: val_loss improved from 0.22073 to 0.21834, saving model to output/checkpoints/weights-mlp.keras
# 1645/1645 [==============================] - 2s 1ms/step - loss: 0.1369 - acc: 0.9665 - val_loss: 0.2183 - val_acc: 0.9665
# Epoch 18/30
# 1638/1645 [============================>.] - ETA: 0s - loss: 0.1337 - acc: 0.9672
# Epoch 18: val_loss did not improve from 0.21834
# 1645/1645 [==============================] - 2s 1ms/step - loss: 0.1338 - acc: 0.9672 - val_loss: 0.2196 - val_acc: 0.9658
# Epoch 19/30
# 1635/1645 [============================>.] - ETA: 0s - loss: 0.1305 - acc: 0.9680
# Epoch 19: val_loss improved from 0.21834 to 0.21577, saving model to output/checkpoints/weights-mlp.keras
# 1645/1645 [==============================] - 2s 1ms/step - loss: 0.1306 - acc: 0.9680 - val_loss: 0.2158 - val_acc: 0.9670
# Epoch 20/30
# 1629/1645 [============================>.] - ETA: 0s - loss: 0.1278 - acc: 0.9684
# Epoch 20: val_loss improved from 0.21577 to 0.21565, saving model to output/checkpoints/weights-mlp.keras
# 1645/1645 [==============================] - 2s 1ms/step - loss: 0.1279 - acc: 0.9684 - val_loss: 0.2157 - val_acc: 0.9670
# Epoch 21/30
# 1626/1645 [============================>.] - ETA: 0s - loss: 0.1250 - acc: 0.9689
# Epoch 21: val_loss did not improve from 0.21565
# 1645/1645 [==============================] - 2s 1ms/step - loss: 0.1249 - acc: 0.9690 - val_loss: 0.2179 - val_acc: 0.9679
# Epoch 22/30
# 1626/1645 [============================>.] - ETA: 0s - loss: 0.1224 - acc: 0.9696
# Epoch 22: val_loss did not improve from 0.21565
# 1645/1645 [==============================] - 2s 1ms/step - loss: 0.1223 - acc: 0.9696 - val_loss: 0.2171 - val_acc: 0.9677
# Epoch 23/30
# 1629/1645 [============================>.] - ETA: 0s - loss: 0.1204 - acc: 0.9701
# Epoch 23: val_loss improved from 0.21565 to 0.21531, saving model to output/checkpoints/weights-mlp.keras
# 1645/1645 [==============================] - 2s 1ms/step - loss: 0.1203 - acc: 0.9701 - val_loss: 0.2153 - val_acc: 0.9679
# Epoch 24/30
# 1612/1645 [============================>.] - ETA: 0s - loss: 0.1177 - acc: 0.9709
# Epoch 24: val_loss improved from 0.21531 to 0.21267, saving model to output/checkpoints/weights-mlp.keras
# 1645/1645 [==============================] - 2s 1ms/step - loss: 0.1178 - acc: 0.9709 - val_loss: 0.2127 - val_acc: 0.9697
# Epoch 25/30
# 1626/1645 [============================>.] - ETA: 0s - loss: 0.1154 - acc: 0.9713
# Epoch 25: val_loss did not improve from 0.21267
# 1645/1645 [==============================] - 2s 1ms/step - loss: 0.1155 - acc: 0.9712 - val_loss: 0.2148 - val_acc: 0.9694
# Epoch 26/30
# 1641/1645 [============================>.] - ETA: 0s - loss: 0.1137 - acc: 0.9717
# Epoch 26: val_loss did not improve from 0.21267
# 1645/1645 [==============================] - 2s 1ms/step - loss: 0.1137 - acc: 0.9717 - val_loss: 0.2138 - val_acc: 0.9702
# Epoch 27/30
# 1631/1645 [============================>.] - ETA: 0s - loss: 0.1116 - acc: 0.9723
# Epoch 27: val_loss did not improve from 0.21267
# 1645/1645 [==============================] - 2s 1ms/step - loss: 0.1116 - acc: 0.9723 - val_loss: 0.2151 - val_acc: 0.9698
# Epoch 28/30
# 1626/1645 [============================>.] - ETA: 0s - loss: 0.1104 - acc: 0.9724
# Epoch 28: val_loss did not improve from 0.21267
# 1645/1645 [==============================] - 2s 1ms/step - loss: 0.1102 - acc: 0.9724 - val_loss: 0.2128 - val_acc: 0.9710
# Epoch 29/30
# 1627/1645 [============================>.] - ETA: 0s - loss: 0.1081 - acc: 0.9730
# Epoch 29: val_loss did not improve from 0.21267
# 1645/1645 [==============================] - 2s 1ms/step - loss: 0.1083 - acc: 0.9729 - val_loss: 0.2161 - val_acc: 0.9699
# Epoch 30/30
# 1619/1645 [============================>.] - ETA: 0s - loss: 0.1070 - acc: 0.9730
# Epoch 30: val_loss improved from 0.21267 to 0.21262, saving model to output/checkpoints/weights-mlp.keras
# 1645/1645 [==============================] - 2s 1ms/step - loss: 0.1069 - acc: 0.9730 - val_loss: 0.2126 - val_acc: 0.9691

# %% [markdown]
# ### test

# %%
# path_test_embeddings = ""
X_test = np.load(EXP.joinpath(path_test_embeddings))
y_test = np.array([dict_labels[l] for l in labels_test])

# %%
pred_probs = model.predict(X_test)
# Out:
#  125/4112 [..............................] - ETA: 1s
# 4112/4112 [==============================] - 2s 366us/step

# %%
y_pred = pred_probs.argmax(axis=1)

# %%
np.save(file=outdir.joinpath("pred_probs.npy"), arr=pred_probs)
np.save(file=outdir.joinpath("labels.npy"), arr=y_test)

# %%
from sklearn.metrics import classification_report

report = classification_report(y_test, y_pred, output_dict=True, 
                               labels = np.array(list(dict_labels.values())),
                               target_names = np.array(list(dict_labels.keys()))
                               )
# Out:
# /home/avila/micromamba/envs/panspace/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/avila/micromamba/envs/panspace/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/avila/micromamba/envs/panspace/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/avila/micromamba/envs/panspace/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/avila/micromamba/envs/panspace/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/avila/micromamba/envs/panspace/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
dict(
    filter(lambda d: d[1]["support"]>0,report.items())
)
# Out:
# {'[clostridium]_bolteae': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 11.0},
#  '[clostridium]_sphenoides': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  '[clostridium]_ultunense': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  '[enterobacter]_lignolyticus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  '[eubacterium]_eligens': {'precision': 0.1,
#   'recall': 0.14285714285714285,
#   'f1-score': 0.11764705882352941,
#   'support': 7.0},
#  '[eubacterium]_hallii': {'precision': 0.5652173913043478,
#   'recall': 0.7222222222222222,
#   'f1-score': 0.6341463414634146,
#   'support': 18.0},
#  '[eubacterium]_rectale': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 5.0},
#  '[eubacterium]_sulci': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  '[haemophilus]_ducreyi': {'precision': 1.0,
#   'recall': 0.6666666666666666,
#   'f1-score': 0.8,
#   'support': 3.0},
#  '[mannheimia]_succiniciproducens': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  '[polyangium]_brachysporum': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'acetobacter_aceti': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'acetobacter_ascendens': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'acetobacter_ghanensis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'acetohalobium_arabaticum': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'acetomicrobium_mobile': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'acholeplasma_laidlawii': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'acholeplasma_oculi': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'achromobacter_insolitus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'achromobacter_sp._aonih1': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'achromobacter_spanius': {'precision': 1.0,
#   'recall': 0.5,
#   'f1-score': 0.6666666666666666,
#   'support': 4.0},
#  'achromobacter_xylosoxidans': {'precision': 0.7692307692307693,
#   'recall': 0.6666666666666666,
#   'f1-score': 0.7142857142857142,
#   'support': 15.0},
#  'acidaminococcus_fermentans': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'acidipropionibacterium_acidipropionici': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 4.0},
#  'acidobacterium_capsulatum': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'acidovorax_avenae': {'precision': 0.6,
#   'recall': 0.75,
#   'f1-score': 0.6666666666666665,
#   'support': 4.0},
#  'acidovorax_carolinensis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 3.0},
#  'acidovorax_cattleyae': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'acidovorax_sp._kks102': {'precision': 0.4,
#   'recall': 0.75,
#   'f1-score': 0.5217391304347827,
#   'support': 8.0},
#  'acinetobacter_baumannii': {'precision': 0.978240302743614,
#   'recall': 0.988527724665392,
#   'f1-score': 0.983357108892059,
#   'support': 1046.0},
#  'acinetobacter_bereziniae': {'precision': 0.5,
#   'recall': 1.0,
#   'f1-score': 0.6666666666666666,
#   'support': 1.0},
#  'acinetobacter_calcoaceticus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 4.0},
#  'acinetobacter_defluvii': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 4.0},
#  'acinetobacter_haemolyticus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'acinetobacter_indicus': {'precision': 0.5,
#   'recall': 1.0,
#   'f1-score': 0.6666666666666666,
#   'support': 1.0},
#  'acinetobacter_johnsonii': {'precision': 0.5454545454545454,
#   'recall': 0.6,
#   'f1-score': 0.5714285714285713,
#   'support': 10.0},
#  'acinetobacter_junii': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'acinetobacter_lactucae': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'acinetobacter_lwoffii': {'precision': 0.6153846153846154,
#   'recall': 0.8,
#   'f1-score': 0.6956521739130435,
#   'support': 10.0},
#  'acinetobacter_nosocomialis': {'precision': 1.0,
#   'recall': 0.16666666666666666,
#   'f1-score': 0.2857142857142857,
#   'support': 18.0},
#  'acinetobacter_pittii': {'precision': 0.7872340425531915,
#   'recall': 0.8604651162790697,
#   'f1-score': 0.8222222222222222,
#   'support': 43.0},
#  'acinetobacter_radioresistens': {'precision': 0.875,
#   'recall': 0.875,
#   'f1-score': 0.875,
#   'support': 8.0},
#  'acinetobacter_schindleri': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 4.0},
#  'acinetobacter_soli': {'precision': 1.0,
#   'recall': 0.75,
#   'f1-score': 0.8571428571428571,
#   'support': 4.0},
#  'acinetobacter_sp._acnih1': {'precision': 0.3333333333333333,
#   'recall': 0.5,
#   'f1-score': 0.4,
#   'support': 2.0},
#  'acinetobacter_sp._adp1': {'precision': 1.0,
#   'recall': 0.8571428571428571,
#   'f1-score': 0.923076923076923,
#   'support': 7.0},
#  'acinetobacter_sp._swby1': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 3.0},
#  'acinetobacter_sp._tth0-4': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'acinetobacter_sp._wcha45': {'precision': 0.7,
#   'recall': 0.7777777777777778,
#   'f1-score': 0.7368421052631577,
#   'support': 9.0},
#  'actinobacillus_pleuropneumoniae': {'precision': 0.95,
#   'recall': 1.0,
#   'f1-score': 0.9743589743589743,
#   'support': 38.0},
#  'actinobacillus_porcitonsillarum': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 4.0},
#  'actinobacillus_succinogenes': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 5.0},
#  'actinobacillus_suis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'actinobacteria_bacterium_imcc19121': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'actinomyces_meyeri': {'precision': 0.5714285714285714,
#   'recall': 0.8,
#   'f1-score': 0.6666666666666666,
#   'support': 5.0},
#  'actinomyces_pacaensis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 3.0},
#  'actinomyces_radicidentis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 3.0},
#  'actinomyces_radingae': {'precision': 0.4,
#   'recall': 0.6666666666666666,
#   'f1-score': 0.5,
#   'support': 3.0},
#  'actinomyces_sp._chiba101': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'actinomyces_sp._oral_taxon_414': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'actinomyces_sp._z16': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'actinoplanes_sp._n902-109': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'actinoplanes_sp._se50/110': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'actinopolymorpha_singaporensis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'actinopolyspora_erythraea': {'precision': 1.0,
#   'recall': 0.5,
#   'f1-score': 0.6666666666666666,
#   'support': 2.0},
#  'acutalibacter_muris': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'adlercreutzia_equolifaciens': {'precision': 0.6,
#   'recall': 1.0,
#   'f1-score': 0.7499999999999999,
#   'support': 3.0},
#  'aerococcus_christensenii': {'precision': 0.6,
#   'recall': 0.5,
#   'f1-score': 0.5454545454545454,
#   'support': 6.0},
#  'aerococcus_sanguinicola': {'precision': 0.6666666666666666,
#   'recall': 1.0,
#   'f1-score': 0.8,
#   'support': 2.0},
#  'aerococcus_urinae': {'precision': 0.8571428571428571,
#   'recall': 1.0,
#   'f1-score': 0.923076923076923,
#   'support': 6.0},
#  'aerococcus_urinaeequi': {'precision': 0.75,
#   'recall': 1.0,
#   'f1-score': 0.8571428571428571,
#   'support': 3.0},
#  'aerococcus_urinaehominis': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'aeromicrobium_sp._592': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'aeromonas_caviae': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 7.0},
#  'aeromonas_hydrophila': {'precision': 0.96875,
#   'recall': 0.8378378378378378,
#   'f1-score': 0.8985507246376812,
#   'support': 37.0},
#  'aeromonas_media': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'aeromonas_salmonicida': {'precision': 0.8,
#   'recall': 1.0,
#   'f1-score': 0.888888888888889,
#   'support': 36.0},
#  'aeromonas_schubertii': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'aeromonas_sp._asnih1': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 17.0},
#  'aeromonas_sp._asnih5': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'aeromonas_sp._asnih7': {'precision': 0.24324324324324326,
#   'recall': 0.9,
#   'f1-score': 0.3829787234042553,
#   'support': 10.0},
#  'aeromonas_sp._cu5': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'aeromonas_veronii': {'precision': 0.8666666666666667,
#   'recall': 0.7428571428571429,
#   'f1-score': 0.8,
#   'support': 35.0},
#  'aggregatibacter_actinomycetemcomitans': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'aggregatibacter_aphrophilus': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 2.0},
#  'agrobacterium_fabrum': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'agrobacterium_rhizogenes': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'agrobacterium_sp._rac06': {'precision': 1.0,
#   'recall': 0.5,
#   'f1-score': 0.6666666666666666,
#   'support': 2.0},
#  'agrobacterium_tumefaciens': {'precision': 0.3125,
#   'recall': 0.7142857142857143,
#   'f1-score': 0.43478260869565216,
#   'support': 7.0},
#  'agrobacterium_vitis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'agrococcus_carbonis': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'agrococcus_jejuensis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'agromyces_aureus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'agromyces_sp._30a': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'akkermansia_muciniphila': {'precision': 1.0,
#   'recall': 0.5,
#   'f1-score': 0.6666666666666666,
#   'support': 2.0},
#  'alcanivorax_borkumensis': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'alcanivorax_sp._n3-2a': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'algibacter_alginicilyticus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'algoriphagus_machipongonensis': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'algoriphagus_sp._m8-2': {'precision': 0.6666666666666666,
#   'recall': 1.0,
#   'f1-score': 0.8,
#   'support': 2.0},
#  'alicyclobacillus_acidocaldarius': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'aliivibrio_fischeri': {'precision': 1.0,
#   'recall': 0.8333333333333334,
#   'f1-score': 0.9090909090909091,
#   'support': 18.0},
#  'aliivibrio_wodanis': {'precision': 0.6666666666666666,
#   'recall': 1.0,
#   'f1-score': 0.8,
#   'support': 2.0},
#  'alistipes_finegoldii': {'precision': 1.0,
#   'recall': 0.8333333333333334,
#   'f1-score': 0.9090909090909091,
#   'support': 6.0},
#  'alistipes_shahii': {'precision': 0.3,
#   'recall': 0.75,
#   'f1-score': 0.4285714285714285,
#   'support': 4.0},
#  'alkalilimnicola_ehrlichii': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'alkaliphilus_metalliredigens': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 3.0},
#  'alpha_proteobacterium_himb5': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 4.0},
#  'altererythrobacter_atlanticus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'alteromonas_mediterranea': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 4.0},
#  'aminobacter_sp._msh1': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'amycolatopsis_albispora': {'precision': 0.3333333333333333,
#   'recall': 0.25,
#   'f1-score': 0.28571428571428575,
#   'support': 4.0},
#  'amycolatopsis_orientalis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'amycolatopsis_sp._aa4': {'precision': 1.0,
#   'recall': 0.5,
#   'f1-score': 0.6666666666666666,
#   'support': 2.0},
#  'anaerococcus_mediterraneensis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'anaerostipes_hadrus': {'precision': 0.75,
#   'recall': 0.375,
#   'f1-score': 0.5,
#   'support': 8.0},
#  'anaerotignum_propionicum': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'anaplasma_phagocytophilum': {'precision': 1.0,
#   'recall': 0.6666666666666666,
#   'f1-score': 0.8,
#   'support': 3.0},
#  'anderseniella_sp._alg231-50': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 3.0},
#  'aneurinibacillus_sp._xh2': {'precision': 0.5,
#   'recall': 1.0,
#   'f1-score': 0.6666666666666666,
#   'support': 1.0},
#  'anoxybacillus_flavithermus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 3.0},
#  'antarctobacter_heliothermus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'aquaspirillum_sp._lm1': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'aquiflexum_balticum': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 2.0},
#  'arcobacter_butzleri': {'precision': 0.75,
#   'recall': 0.5,
#   'f1-score': 0.6,
#   'support': 12.0},
#  'arcobacter_halophilus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'arcobacter_mytili': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'arcobacter_nitrofigilis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'arcobacter_sp._l': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'arcobacter_trophiarum': {'precision': 0.38461538461538464,
#   'recall': 1.0,
#   'f1-score': 0.5555555555555556,
#   'support': 5.0},
#  'arenibacter_algicola': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'arthrobacter_alpinus': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'arthrobacter_crystallopoietes': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'arthrobacter_sp._fb24': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'arthrobacter_sp._qxt-31': {'precision': 0.8,
#   'recall': 1.0,
#   'f1-score': 0.888888888888889,
#   'support': 12.0},
#  'arthrobacter_sp._u41': {'precision': 0.5,
#   'recall': 1.0,
#   'f1-score': 0.6666666666666666,
#   'support': 1.0},
#  'arthrobacter_sp._yn': {'precision': 0.8,
#   'recall': 0.8,
#   'f1-score': 0.8000000000000002,
#   'support': 5.0},
#  'arthrobacter_sp._zxy-2': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'asaia_bogorensis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'atopobium_parvulum': {'precision': 0.5,
#   'recall': 0.5,
#   'f1-score': 0.5,
#   'support': 2.0},
#  'aureimonas_sp._au20': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'azoarcus_communis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'azotobacter_chroococcum': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'bacillus_anthracis': {'precision': 0.510548523206751,
#   'recall': 0.952755905511811,
#   'f1-score': 0.6648351648351649,
#   'support': 127.0},
#  'bacillus_beveridgei': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'bacillus_cereus': {'precision': 0.5686274509803921,
#   'recall': 0.23387096774193547,
#   'f1-score': 0.3314285714285714,
#   'support': 124.0},
#  'bacillus_coagulans': {'precision': 0.6666666666666666,
#   'recall': 0.5,
#   'f1-score': 0.5714285714285715,
#   'support': 4.0},
#  'bacillus_filamentosus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'bacillus_glycinifermentans': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'bacillus_infantis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'bacillus_licheniformis': {'precision': 1.0,
#   'recall': 0.07692307692307693,
#   'f1-score': 0.14285714285714288,
#   'support': 13.0},
#  'bacillus_megaterium': {'precision': 0.7142857142857143,
#   'recall': 0.7142857142857143,
#   'f1-score': 0.7142857142857143,
#   'support': 7.0},
#  'bacillus_methanolicus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'bacillus_mycoides': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 17.0},
#  'bacillus_oceanisediminis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'bacillus_pseudomycoides': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 3.0},
#  'bacillus_pumilus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'bacillus_safensis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'bacillus_simplex': {'precision': 0.25,
#   'recall': 0.5,
#   'f1-score': 0.3333333333333333,
#   'support': 2.0},
#  'bacillus_sp._fjat-22090': {'precision': 0.5,
#   'recall': 0.25,
#   'f1-score': 0.3333333333333333,
#   'support': 4.0},
#  'bacillus_sp._x1(2014)': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'bacillus_subtilis': {'precision': 0.851063829787234,
#   'recall': 0.8955223880597015,
#   'f1-score': 0.8727272727272728,
#   'support': 134.0},
#  'bacillus_thermoamylovorans': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'bacillus_thuringiensis': {'precision': 0.6956521739130435,
#   'recall': 0.3902439024390244,
#   'f1-score': 0.5000000000000001,
#   'support': 41.0},
#  'bacillus_velezensis': {'precision': 0.875,
#   'recall': 1.0,
#   'f1-score': 0.9333333333333333,
#   'support': 7.0},
#  'bacillus_weihaiensis': {'precision': 0.5,
#   'recall': 1.0,
#   'f1-score': 0.6666666666666666,
#   'support': 1.0},
#  'bacillus_wiedmannii': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 3.0},
#  'bacterium_2013arg42i': {'precision': 1.0,
#   'recall': 0.6666666666666666,
#   'f1-score': 0.8,
#   'support': 3.0},
#  'bacteroides_caccae': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'bacteroides_caecimuris': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'bacteroides_cellulosilyticus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 5.0},
#  'bacteroides_dorei': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 5.0},
#  'bacteroides_fragilis': {'precision': 0.6458333333333334,
#   'recall': 0.7948717948717948,
#   'f1-score': 0.7126436781609194,
#   'support': 39.0},
#  'bacteroides_helcogenes': {'precision': 0.42857142857142855,
#   'recall': 0.8181818181818182,
#   'f1-score': 0.5625,
#   'support': 11.0},
#  'bacteroides_ovatus': {'precision': 0.5,
#   'recall': 0.75,
#   'f1-score': 0.6,
#   'support': 8.0},
#  'bacteroides_salanitronis': {'precision': 1.0,
#   'recall': 0.6666666666666666,
#   'f1-score': 0.8,
#   'support': 6.0},
#  'bacteroides_thetaiotaomicron': {'precision': 0.3333333333333333,
#   'recall': 0.06666666666666667,
#   'f1-score': 0.1111111111111111,
#   'support': 15.0},
#  'bacteroides_vulgatus': {'precision': 0.35714285714285715,
#   'recall': 1.0,
#   'f1-score': 0.5263157894736842,
#   'support': 5.0},
#  'bacteroidetes_bacterium_omega': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'barnesiella_viscericola': {'precision': 0.5,
#   'recall': 0.3333333333333333,
#   'f1-score': 0.4,
#   'support': 3.0},
#  'bartonella_bacilliformis': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 5.0},
#  'bartonella_birtlesii': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'bartonella_bovis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'bartonella_henselae': {'precision': 1.0,
#   'recall': 0.3333333333333333,
#   'f1-score': 0.5,
#   'support': 3.0},
#  'bartonella_quintana': {'precision': 0.6666666666666666,
#   'recall': 1.0,
#   'f1-score': 0.8,
#   'support': 4.0},
#  'bartonella_schoenbuchensis': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'belliella_baltica': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'bifidobacterium_actinocoloniiforme': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'bifidobacterium_adolescentis': {'precision': 1.0,
#   'recall': 0.5,
#   'f1-score': 0.6666666666666666,
#   'support': 2.0},
#  'bifidobacterium_angulatum': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'bifidobacterium_animalis': {'precision': 0.6666666666666666,
#   'recall': 1.0,
#   'f1-score': 0.8,
#   'support': 2.0},
#  'bifidobacterium_bifidum': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 4.0},
#  'bifidobacterium_breve': {'precision': 0.875,
#   'recall': 1.0,
#   'f1-score': 0.9333333333333333,
#   'support': 7.0},
#  'bifidobacterium_choerinum': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'bifidobacterium_coryneforme': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'bifidobacterium_longum': {'precision': 0.625,
#   'recall': 0.8333333333333334,
#   'f1-score': 0.7142857142857143,
#   'support': 18.0},
#  'bifidobacterium_pseudolongum': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'bifidobacterium_scardovii': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'bifidobacterium_thermophilum': {'precision': 0.6666666666666666,
#   'recall': 0.5,
#   'f1-score': 0.5714285714285715,
#   'support': 4.0},
#  'blautia_hansenii': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 7.0},
#  'blautia_sp._n6h1-15': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'blautia_sp._yl58': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 4.0},
#  'bordetella_avium': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'bordetella_bronchiseptica': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 9.0},
#  'bordetella_genomosp._6': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'bordetella_genomosp._8': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'bordetella_hinzii': {'precision': 0.5,
#   'recall': 1.0,
#   'f1-score': 0.6666666666666666,
#   'support': 4.0},
#  'bordetella_holmesii': {'precision': 1.0,
#   'recall': 0.875,
#   'f1-score': 0.9333333333333333,
#   'support': 8.0},
#  'bordetella_pertussis': {'precision': 0.952191235059761,
#   'recall': 0.9958333333333333,
#   'f1-score': 0.9735234215885947,
#   'support': 240.0},
#  'bordetella_petrii': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'bordetella_pseudohinzii': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 3.0},
#  'borrelia_miyamotoi': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'borrelia_recurrentis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'borreliella_afzelii': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'borreliella_bavariensis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 3.0},
#  'borreliella_burgdorferi': {'precision': 0.6901408450704225,
#   'recall': 1.0,
#   'f1-score': 0.8166666666666667,
#   'support': 49.0},
#  'borreliella_garinii': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 6.0},
#  'borreliella_valaisiana': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'bosea_sp._as-1': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'bosea_vaviloviae': {'precision': 1.0,
#   'recall': 0.5,
#   'f1-score': 0.6666666666666666,
#   'support': 2.0},
#  'brachyspira_hyodysenteriae': {'precision': 0.75,
#   'recall': 1.0,
#   'f1-score': 0.8571428571428571,
#   'support': 3.0},
#  'brachyspira_murdochii': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'bradyrhizobiaceae_bacterium_sg-6c': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'bradyrhizobium_diazoefficiens': {'precision': 0.42857142857142855,
#   'recall': 1.0,
#   'f1-score': 0.6,
#   'support': 9.0},
#  'bradyrhizobium_erythrophlei': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'bradyrhizobium_icense': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'bradyrhizobium_japonicum': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 5.0},
#  'bradyrhizobium_lablabi': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'bradyrhizobium_ottawaense': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 5.0},
#  'bradyrhizobium_sp._sk17': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 5.0},
#  'brenneria_sp._enid312': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'brevibacillus_brevis': {'precision': 0.6666666666666666,
#   'recall': 0.3333333333333333,
#   'f1-score': 0.4444444444444444,
#   'support': 6.0},
#  'brevibacterium_linens': {'precision': 0.75,
#   'recall': 0.6,
#   'f1-score': 0.6666666666666665,
#   'support': 5.0},
#  'brevundimonas_diminuta': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'brevundimonas_sp._ds20': {'precision': 0.5,
#   'recall': 0.5,
#   'f1-score': 0.5,
#   'support': 2.0},
#  'brucella_abortus': {'precision': 0.5555555555555556,
#   'recall': 0.2604166666666667,
#   'f1-score': 0.35460992907801414,
#   'support': 96.0},
#  'brucella_canis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 9.0},
#  'brucella_ceti': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 7.0},
#  'brucella_melitensis': {'precision': 0.2891566265060241,
#   'recall': 0.8571428571428571,
#   'f1-score': 0.43243243243243246,
#   'support': 56.0},
#  'brucella_ovis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 5.0},
#  'brucella_pinnipedialis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 4.0},
#  'brucella_sp._09rb8910': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'brucella_suis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 34.0},
#  'buchnera_aphidicola': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'burkholderia_ambifaria': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 14.0},
#  'burkholderia_cenocepacia': {'precision': 0.7397260273972602,
#   'recall': 0.72,
#   'f1-score': 0.7297297297297296,
#   'support': 75.0},
#  'burkholderia_cepacia': {'precision': 0.3023255813953488,
#   'recall': 0.896551724137931,
#   'f1-score': 0.45217391304347815,
#   'support': 29.0},
#  'burkholderia_contaminans': {'precision': 0.7916666666666666,
#   'recall': 1.0,
#   'f1-score': 0.8837209302325582,
#   'support': 19.0},
#  'burkholderia_diffusa': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 3.0},
#  'burkholderia_dolosa': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 9.0},
#  'burkholderia_gladioli': {'precision': 0.9830508474576272,
#   'recall': 1.0,
#   'f1-score': 0.9914529914529915,
#   'support': 58.0},
#  'burkholderia_glumae': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'burkholderia_humptydooensis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'burkholderia_insecticola': {'precision': 1.0,
#   'recall': 0.6666666666666666,
#   'f1-score': 0.8,
#   'support': 3.0},
#  'burkholderia_mallei': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 16.0},
#  'burkholderia_metallica': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 3.0},
#  'burkholderia_multivorans': {'precision': 0.9565217391304348,
#   'recall': 0.9565217391304348,
#   'f1-score': 0.9565217391304348,
#   'support': 23.0},
#  'burkholderia_pseudomallei': {'precision': 0.938375350140056,
#   'recall': 0.9970238095238095,
#   'f1-score': 0.9668109668109668,
#   'support': 336.0},
#  'burkholderia_seminalis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'burkholderia_sp._2002721687': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'burkholderia_sp._bp7605': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'burkholderia_sp._ccge1003': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'burkholderia_sp._ido3': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 3.0},
#  'burkholderia_sp._jp2-270': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'burkholderia_sp._msmb0266': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'burkholderia_sp._msmb0852': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'burkholderia_sp._msmb0856': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'burkholderia_sp._msmb1588': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'burkholderia_sp._msmb617wgs': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'burkholderia_sp._nrf60-bp8': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 4.0},
#  'burkholderia_stabilis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 6.0},
#  'burkholderia_stagnalis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 10.0},
#  'burkholderia_territorii': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 6.0},
#  'burkholderia_thailandensis': {'precision': 0.2222222222222222,
#   'recall': 0.25,
#   'f1-score': 0.23529411764705882,
#   'support': 8.0},
#  'burkholderia_ubonensis': {'precision': 0.6666666666666666,
#   'recall': 1.0,
#   'f1-score': 0.8,
#   'support': 50.0},
#  'burkholderia_vietnamiensis': {'precision': 0.8888888888888888,
#   'recall': 0.3076923076923077,
#   'f1-score': 0.4571428571428572,
#   'support': 26.0},
#  'burkholderiales_bacterium_joshi_001': {'precision': 1.0,
#   'recall': 0.5,
#   'f1-score': 0.6666666666666666,
#   'support': 2.0},
#  'butyrivibrio_fibrisolvens': {'precision': 0.25,
#   'recall': 0.5,
#   'f1-score': 0.3333333333333333,
#   'support': 6.0},
#  'butyrivibrio_hungatei': {'precision': 0.2,
#   'recall': 0.5,
#   'f1-score': 0.28571428571428575,
#   'support': 2.0},
#  'butyrivibrio_proteoclasticus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 4.0},
#  'caldicellulosiruptor_hydrothermalis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'caldicellulosiruptor_saccharolyticus': {'precision': 1.0,
#   'recall': 0.5,
#   'f1-score': 0.6666666666666666,
#   'support': 2.0},
#  'calditerrivibrio_nitroreducens': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'calothrix_parietina': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'calothrix_sp._nies-4071': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'calothrix_sp._pcc_7507': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'campylobacter_coli': {'precision': 0.9972914409534128,
#   'recall': 0.9871313672922252,
#   'f1-score': 0.9921853947722986,
#   'support': 1865.0},
#  'campylobacter_concisus': {'precision': 0.9411764705882353,
#   'recall': 0.9411764705882353,
#   'f1-score': 0.9411764705882353,
#   'support': 17.0},
#  'campylobacter_curvus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'campylobacter_fetus': {'precision': 0.9827586206896551,
#   'recall': 0.9827586206896551,
#   'f1-score': 0.9827586206896551,
#   'support': 58.0},
#  'campylobacter_helveticus': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 78.0},
#  'campylobacter_hyointestinalis': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 9.0},
#  'campylobacter_insulaenigrae': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'campylobacter_jejuni': {'precision': 0.9953990444169174,
#   'recall': 0.9975172902996985,
#   'f1-score': 0.9964570416297609,
#   'support': 5639.0},
#  'campylobacter_lanienae': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 10.0},
#  'campylobacter_lari': {'precision': 0.9655172413793104,
#   'recall': 1.0,
#   'f1-score': 0.9824561403508771,
#   'support': 56.0},
#  'campylobacter_pinnipediorum': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'campylobacter_sp._nctc_13003': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 12.0},
#  'campylobacter_sp._rm6137': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'campylobacter_sputorum': {'precision': 0.6,
#   'recall': 1.0,
#   'f1-score': 0.7499999999999999,
#   'support': 3.0},
#  'campylobacter_subantarcticus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'campylobacter_ureolyticus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 3.0},
#  'campylobacter_volucris': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'candidatus_cloacimonas_acidaminovorans': {'precision': 0.3333333333333333,
#   'recall': 0.5,
#   'f1-score': 0.4,
#   'support': 2.0},
#  'candidatus_desulforudis_audaxviator': {'precision': 0.5,
#   'recall': 1.0,
#   'f1-score': 0.6666666666666666,
#   'support': 1.0},
#  'candidatus_fonsibacter_ubiquis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'candidatus_hamiltonella_defensa': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'candidatus_koribacter_versatilis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'candidatus_nanopelagicus_limnes': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'candidatus_paracaedibacter_acanthamoebae': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'candidatus_pelagibacter_sp._himb1321': {'precision': 0.3076923076923077,
#   'recall': 0.6666666666666666,
#   'f1-score': 0.42105263157894735,
#   'support': 6.0},
#  'candidatus_pelagibacter_sp._rs39': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 4.0},
#  'candidatus_pelagibacter_sp._rs40': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 3.0},
#  'candidatus_pelagibacter_ubique': {'precision': 0.25,
#   'recall': 0.5,
#   'f1-score': 0.3333333333333333,
#   'support': 2.0},
#  'candidatus_planktophila_lacus': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'candidatus_planktophila_vernalis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'candidatus_planktophila_versatilis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'candidatus_puniceispirillum_marinum': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'candidatus_saccharibacteria_oral_taxon_tm7x': {'precision': 0.6666666666666666,
#   'recall': 0.6666666666666666,
#   'f1-score': 0.6666666666666666,
#   'support': 3.0},
#  'candidatus_tachikawaea_gelatinosa': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'candidatus_thioglobus_autotrophicus': {'precision': 0.25,
#   'recall': 1.0,
#   'f1-score': 0.4,
#   'support': 1.0},
#  'candidatus_thioglobus_singularis': {'precision': 0.8571428571428571,
#   'recall': 1.0,
#   'f1-score': 0.923076923076923,
#   'support': 6.0},
#  'capnocytophaga_canimorsus': {'precision': 0.5,
#   'recall': 1.0,
#   'f1-score': 0.6666666666666666,
#   'support': 1.0},
#  'capnocytophaga_gingivalis': {'precision': 0.5,
#   'recall': 1.0,
#   'f1-score': 0.6666666666666666,
#   'support': 1.0},
#  'capnocytophaga_leadbetteri': {'precision': 0.6666666666666666,
#   'recall': 1.0,
#   'f1-score': 0.8,
#   'support': 4.0},
#  'capnocytophaga_ochracea': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 2.0},
#  'capnocytophaga_sp._h4358': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'capnocytophaga_sp._oral_taxon_878': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'capnocytophaga_sputigena': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'carboxydothermus_hydrogenoformans': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 2.0},
#  'carnobacterium_maltaromaticum': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'caulobacter_sp._k31': {'precision': 0.5,
#   'recall': 0.5,
#   'f1-score': 0.5,
#   'support': 4.0},
#  'caulobacter_vibrioides': {'precision': 0.9583333333333334,
#   'recall': 0.92,
#   'f1-score': 0.9387755102040817,
#   'support': 25.0},
#  'cedecea_neteri': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'celeribacter_baekdonensis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'celeribacter_ethanolicus': {'precision': 0.14285714285714285,
#   'recall': 1.0,
#   'f1-score': 0.25,
#   'support': 1.0},
#  'celeribacter_indicus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'celeribacter_marinus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'cellulomonas_fimi': {'precision': 0.6,
#   'recall': 1.0,
#   'f1-score': 0.7499999999999999,
#   'support': 3.0},
#  'cellulomonas_flavigena': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'cellulophaga_baltica': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'cellulophaga_lytica': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'cellulosimicrobium_sp._th-20': {'precision': 0.5,
#   'recall': 0.5,
#   'f1-score': 0.5,
#   'support': 2.0},
#  'chitinophaga_caeni': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'chitinophaga_pinensis': {'precision': 1.0,
#   'recall': 0.6666666666666666,
#   'f1-score': 0.8,
#   'support': 3.0},
#  'chlamydia_abortus': {'precision': 0.8571428571428571,
#   'recall': 0.8,
#   'f1-score': 0.8275862068965518,
#   'support': 15.0},
#  'chlamydia_avium': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'chlamydia_pecorum': {'precision': 0.875,
#   'recall': 1.0,
#   'f1-score': 0.9333333333333333,
#   'support': 28.0},
#  'chlamydia_pneumoniae': {'precision': 0.5,
#   'recall': 1.0,
#   'f1-score': 0.6666666666666666,
#   'support': 1.0},
#  'chlamydia_psittaci': {'precision': 0.875,
#   'recall': 0.7777777777777778,
#   'f1-score': 0.823529411764706,
#   'support': 9.0},
#  'chlamydia_sp._h15-1957-10c': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'chlamydia_suis': {'precision': 1.0,
#   'recall': 0.4444444444444444,
#   'f1-score': 0.6153846153846153,
#   'support': 9.0},
#  'chlamydia_trachomatis': {'precision': 0.9108527131782945,
#   'recall': 0.9832635983263598,
#   'f1-score': 0.9456740442655934,
#   'support': 239.0},
#  'chlorobium_phaeobacteroides': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'chondromyces_crocatus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'chromobacterium_vaccinii': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'chromobacterium_violaceum': {'precision': 1.0,
#   'recall': 0.3333333333333333,
#   'f1-score': 0.5,
#   'support': 3.0},
#  'chryseobacterium_glaciei': {'precision': 0.6666666666666666,
#   'recall': 0.5,
#   'f1-score': 0.5714285714285715,
#   'support': 8.0},
#  'chryseobacterium_indologenes': {'precision': 0.9230769230769231,
#   'recall': 1.0,
#   'f1-score': 0.9600000000000001,
#   'support': 12.0},
#  'chryseobacterium_piperi': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'chryseobacterium_sp._ihb_b_17019': {'precision': 1.0,
#   'recall': 0.5,
#   'f1-score': 0.6666666666666666,
#   'support': 2.0},
#  'chryseobacterium_taklimakanense': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'citrobacter_amalonaticus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'citrobacter_braakii': {'precision': 0.9230769230769231,
#   'recall': 0.9230769230769231,
#   'f1-score': 0.9230769230769231,
#   'support': 13.0},
#  'citrobacter_farmeri': {'precision': 1.0,
#   'recall': 0.3333333333333333,
#   'f1-score': 0.5,
#   'support': 3.0},
#  'citrobacter_freundii': {'precision': 0.8604651162790697,
#   'recall': 0.9487179487179487,
#   'f1-score': 0.9024390243902439,
#   'support': 78.0},
#  'citrobacter_freundii_complex_sp._cfnih4': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'citrobacter_koseri': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 10.0},
#  'citrobacter_rodentium': {'precision': 0.8571428571428571,
#   'recall': 0.9,
#   'f1-score': 0.8780487804878048,
#   'support': 20.0},
#  'citrobacter_sp._86': {'precision': 0.26666666666666666,
#   'recall': 1.0,
#   'f1-score': 0.4210526315789474,
#   'support': 4.0},
#  'citrobacter_sp._92': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'citrobacter_sp._cfnih10': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'citrobacter_sp._fdaargos_156': {'precision': 0.5,
#   'recall': 0.1111111111111111,
#   'f1-score': 0.1818181818181818,
#   'support': 9.0},
#  'citrobacter_werkmanii': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 6.0},
#  'clavibacter_insidiosus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'clavibacter_michiganensis': {'precision': 0.6666666666666666,
#   'recall': 1.0,
#   'f1-score': 0.8,
#   'support': 4.0},
#  'clavibacter_nebraskensis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'cloacibacillus_porcorum': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'clostridiaceae_bacterium_14s0207': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'clostridioides_difficile': {'precision': 0.9948472580051527,
#   'recall': 0.9915627292736611,
#   'f1-score': 0.9932022781554289,
#   'support': 2726.0},
#  'clostridium_aceticum': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'clostridium_autoethanogenum': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'clostridium_baratii': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'clostridium_beijerinckii': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 3.0},
#  'clostridium_botulinum': {'precision': 0.9072164948453608,
#   'recall': 0.9565217391304348,
#   'f1-score': 0.9312169312169312,
#   'support': 92.0},
#  'clostridium_butyricum': {'precision': 0.3333333333333333,
#   'recall': 1.0,
#   'f1-score': 0.5,
#   'support': 2.0},
#  'clostridium_carboxidivorans': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'clostridium_chauvoei': {'precision': 1.0,
#   'recall': 0.6666666666666666,
#   'f1-score': 0.8,
#   'support': 6.0},
#  'clostridium_cochlearium': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'clostridium_ljungdahlii': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'clostridium_perfringens': {'precision': 0.9714285714285714,
#   'recall': 1.0,
#   'f1-score': 0.9855072463768115,
#   'support': 102.0},
#  'clostridium_scatologenes': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'clostridium_sp._bnl1100': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'clostridium_sp._mf28': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'clostridium_tetani': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'collimonas_fungivorans': {'precision': 0.5,
#   'recall': 1.0,
#   'f1-score': 0.6666666666666666,
#   'support': 1.0},
#  'collinsella_aerofaciens': {'precision': 1.0,
#   'recall': 0.25,
#   'f1-score': 0.4,
#   'support': 4.0},
#  'colwellia_psychrerythraea': {'precision': 0.96,
#   'recall': 1.0,
#   'f1-score': 0.9795918367346939,
#   'support': 24.0},
#  'comamonas_aquatica': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'comamonas_kerstersii': {'precision': 0.6666666666666666,
#   'recall': 0.6666666666666666,
#   'f1-score': 0.6666666666666666,
#   'support': 3.0},
#  'comamonas_testosteroni': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'conexibacter_woesei': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'confluentimicrobium_sp._emb200-ns6': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'corynebacterium_ammoniagenes': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'corynebacterium_atypicum': {'precision': 0.6666666666666666,
#   'recall': 1.0,
#   'f1-score': 0.8,
#   'support': 2.0},
#  'corynebacterium_aurimucosum': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 10.0},
#  'corynebacterium_crudilactis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'corynebacterium_diphtheriae': {'precision': 0.9310344827586207,
#   'recall': 0.9310344827586207,
#   'f1-score': 0.9310344827586207,
#   'support': 29.0},
#  'corynebacterium_frankenforstense': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'corynebacterium_genitalium': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'corynebacterium_glutamicum': {'precision': 0.6666666666666666,
#   'recall': 0.4444444444444444,
#   'f1-score': 0.5333333333333333,
#   'support': 9.0},
#  'corynebacterium_imitans': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'corynebacterium_jeikeium': {'precision': 0.6923076923076923,
#   'recall': 0.9,
#   'f1-score': 0.7826086956521738,
#   'support': 10.0},
#  'corynebacterium_kroppenstedtii': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'corynebacterium_minutissimum': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'corynebacterium_simulans': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'corynebacterium_sp._atcc_6931': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'corynebacterium_sp._nml98-0116': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'corynebacterium_sphenisci': {'precision': 0.6666666666666666,
#   'recall': 1.0,
#   'f1-score': 0.8,
#   'support': 2.0},
#  'corynebacterium_striatum': {'precision': 0.75,
#   'recall': 0.75,
#   'f1-score': 0.75,
#   'support': 12.0},
#  'corynebacterium_terpenotabidum': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'corynebacterium_ulcerans': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'corynebacterium_ureicelerivorans': {'precision': 0.6666666666666666,
#   'recall': 1.0,
#   'f1-score': 0.8,
#   'support': 2.0},
#  'coxiella_burnetii': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 10.0},
#  'cronobacter_dublinensis': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 4.0},
#  'cronobacter_malonaticus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 6.0},
#  'cronobacter_muytjensii': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'cronobacter_sakazakii': {'precision': 0.8666666666666667,
#   'recall': 1.0,
#   'f1-score': 0.9285714285714286,
#   'support': 52.0},
#  'cronobacter_turicensis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 3.0},
#  'cupriavidus_gilardii': {'precision': 0.3333333333333333,
#   'recall': 1.0,
#   'f1-score': 0.5,
#   'support': 1.0},
# ...
#   'f1-score': 0.6666666666666666,
#   'support': 2.0},
#  'mycobacterium_tuberculosis': {'precision': 0.9877124718410814,
#   'recall': 0.9941255281871586,
#   'f1-score': 0.9909086239663055,
#   'support': 9703.0},
#  'mycobacterium_ulcerans': {'precision': 0.95,
#   'recall': 0.9884393063583815,
#   'f1-score': 0.9688385269121813,
#   'support': 173.0},
#  'mycobacteroides_abscessus': {'precision': 0.9858156028368794,
#   'recall': 0.9893238434163701,
#   'f1-score': 0.9875666074600357,
#   'support': 562.0},
#  'mycobacteroides_chelonae': {'precision': 0.9,
#   'recall': 0.9782608695652174,
#   'f1-score': 0.9375,
#   'support': 46.0},
#  'mycobacteroides_immunogenum': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 3.0},
#  'mycolicibacter_sinensis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'mycolicibacter_terrae': {'precision': 1.0,
#   'recall': 0.2,
#   'f1-score': 0.33333333333333337,
#   'support': 5.0},
#  'mycolicibacterium_fortuitum': {'precision': 0.625,
#   'recall': 0.8823529411764706,
#   'f1-score': 0.7317073170731708,
#   'support': 17.0},
#  'mycolicibacterium_gilvum': {'precision': 0.3333333333333333,
#   'recall': 1.0,
#   'f1-score': 0.5,
#   'support': 1.0},
#  'mycolicibacterium_goodii': {'precision': 0.3333333333333333,
#   'recall': 1.0,
#   'f1-score': 0.5,
#   'support': 1.0},
#  'mycolicibacterium_neoaurum': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'mycolicibacterium_rutilum': {'precision': 0.7,
#   'recall': 1.0,
#   'f1-score': 0.8235294117647058,
#   'support': 7.0},
#  'mycolicibacterium_smegmatis': {'precision': 0.9642857142857143,
#   'recall': 0.9310344827586207,
#   'f1-score': 0.9473684210526316,
#   'support': 29.0},
#  'mycolicibacterium_thermoresistibile': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'mycolicibacterium_vaccae': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'mycoplasma_agalactiae': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 12.0},
#  'mycoplasma_anseris': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'mycoplasma_arginini': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'mycoplasma_bovis': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 24.0},
#  'mycoplasma_flocculare': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 3.0},
#  'mycoplasma_gallisepticum': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 13.0},
#  'mycoplasma_genitalium': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 5.0},
#  'mycoplasma_hominis': {'precision': 0.75,
#   'recall': 0.8571428571428571,
#   'f1-score': 0.7999999999999999,
#   'support': 7.0},
#  'mycoplasma_hyopneumoniae': {'precision': 0.8846153846153846,
#   'recall': 1.0,
#   'f1-score': 0.9387755102040816,
#   'support': 23.0},
#  'mycoplasma_hyorhinis': {'precision': 0.5,
#   'recall': 0.6666666666666666,
#   'f1-score': 0.5714285714285715,
#   'support': 3.0},
#  'mycoplasma_pneumoniae': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 22.0},
#  'myroides_odoratimimus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'myroides_sp._a21': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'myxococcus_xanthus': {'precision': 0.625,
#   'recall': 1.0,
#   'f1-score': 0.7692307692307693,
#   'support': 5.0},
#  'nakamurella_multipartita': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'ndongobacter_massiliensis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'negativicoccus_massiliensis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'neisseria_cinerea': {'precision': 0.75,
#   'recall': 0.75,
#   'f1-score': 0.75,
#   'support': 4.0},
#  'neisseria_elongata': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 2.0},
#  'neisseria_gonorrhoeae': {'precision': 0.9943084803642572,
#   'recall': 0.9943084803642572,
#   'f1-score': 0.9943084803642572,
#   'support': 1757.0},
#  'neisseria_lactamica': {'precision': 0.9903381642512077,
#   'recall': 0.9808612440191388,
#   'f1-score': 0.9855769230769231,
#   'support': 209.0},
#  'neisseria_meningitidis': {'precision': 0.9945776255707762,
#   'recall': 0.9991399082568807,
#   'f1-score': 0.9968535469107551,
#   'support': 3488.0},
#  'neisseria_mucosa': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 5.0},
#  'neisseria_polysaccharea': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 6.0},
#  'neisseria_sicca': {'precision': 0.5714285714285714,
#   'recall': 0.8,
#   'f1-score': 0.6666666666666666,
#   'support': 5.0},
#  'neisseria_sp._10022': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'neisseria_sp._10023': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'neisseria_sp._kem232': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 2.0},
#  'neisseria_subflava': {'precision': 0.9230769230769231,
#   'recall': 0.9230769230769231,
#   'f1-score': 0.9230769230769231,
#   'support': 26.0},
#  'neisseria_zoodegmatis': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 2.0},
#  'neomicrococcus_aestuarii': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 3.0},
#  'neorhizobium_galegae': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 3.0},
#  'niastella_koreensis': {'precision': 0.2,
#   'recall': 1.0,
#   'f1-score': 0.33333333333333337,
#   'support': 1.0},
#  'nitratireductor_sp._om-1': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'nitrosomonas_communis': {'precision': 0.5,
#   'recall': 0.5,
#   'f1-score': 0.5,
#   'support': 4.0},
#  'nitrosomonas_eutropha': {'precision': 0.3333333333333333,
#   'recall': 0.3333333333333333,
#   'f1-score': 0.3333333333333333,
#   'support': 3.0},
#  'nitrosomonas_sp._is79a3': {'precision': 0.5,
#   'recall': 0.3333333333333333,
#   'f1-score': 0.4,
#   'support': 6.0},
#  'nitrosomonas_ureae': {'precision': 0.3333333333333333,
#   'recall': 1.0,
#   'f1-score': 0.5,
#   'support': 1.0},
#  'nitrosospira_briensis': {'precision': 0.5714285714285714,
#   'recall': 1.0,
#   'f1-score': 0.7272727272727273,
#   'support': 4.0},
#  'nitrosospira_lacus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'nocardia_brasiliensis': {'precision': 0.5555555555555556,
#   'recall': 0.8333333333333334,
#   'f1-score': 0.6666666666666667,
#   'support': 6.0},
#  'nocardia_cyriacigeorgica': {'precision': 0.6774193548387096,
#   'recall': 1.0,
#   'f1-score': 0.8076923076923077,
#   'support': 21.0},
#  'nocardia_farcinica': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 3.0},
#  'nocardia_nova': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 8.0},
#  'nocardia_seriolae': {'precision': 1.0,
#   'recall': 0.6666666666666666,
#   'f1-score': 0.8,
#   'support': 3.0},
#  'nocardia_soli': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'nocardia_terpenica': {'precision': 0.75,
#   'recall': 0.75,
#   'f1-score': 0.75,
#   'support': 4.0},
#  'nocardioides_sp._cf8': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'nocardioides_sp._js614': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'nocardiopsis_alba': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'nocardiopsis_dassonvillei': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'nodularia_spumigena': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'nonlabens_dokdonensis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'nostoc_sp._nies-4103': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'novosphingobium_aromaticivorans': {'precision': 1.0,
#   'recall': 0.5,
#   'f1-score': 0.6666666666666666,
#   'support': 6.0},
#  'novosphingobium_resinovorum': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'novosphingobium_sp._pp1y': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'oceanimonas_sp._gk1': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'oceanobacillus_iheyensis': {'precision': 1.0,
#   'recall': 0.5,
#   'f1-score': 0.6666666666666666,
#   'support': 2.0},
#  'oceanobacillus_kimchii': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'ochrobactrum_anthropi': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 9.0},
#  'ochrobactrum_pseudogrignonense': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'ochrobactrum_sp._a44': {'precision': 0.5,
#   'recall': 1.0,
#   'f1-score': 0.6666666666666666,
#   'support': 1.0},
#  'octadecabacter_temperatus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'odoribacter_splanchnicus': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'oenococcus_oeni': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 26.0},
#  'oligella_urethralis': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'olleya_aquimaris': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'olsenella_sp._marseille-p2300': {'precision': 0.5,
#   'recall': 1.0,
#   'f1-score': 0.6666666666666666,
#   'support': 1.0},
#  'olsenella_uli': {'precision': 0.5,
#   'recall': 0.5,
#   'f1-score': 0.5,
#   'support': 2.0},
#  'olsenella_umbonata': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'opitutaceae_bacterium_tav5': {'precision': 0.8,
#   'recall': 1.0,
#   'f1-score': 0.888888888888889,
#   'support': 4.0},
#  'opitutus_sp._gas368': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'orientia_tsutsugamushi': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 10.0},
#  'oscillatoria_nigro-viridis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'oscillibacter_valericigenes': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'oxalobacter_formigenes': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'paenibacillus_glucanolyticus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 3.0},
#  'paenibacillus_kribbensis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'paenibacillus_larvae': {'precision': 0.9615384615384616,
#   'recall': 0.9615384615384616,
#   'f1-score': 0.9615384615384616,
#   'support': 26.0},
#  'paenibacillus_mucilaginosus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'paenibacillus_odorifer': {'precision': 0.7,
#   'recall': 1.0,
#   'f1-score': 0.8235294117647058,
#   'support': 7.0},
#  'paenibacillus_polymyxa': {'precision': 0.1875,
#   'recall': 0.6,
#   'f1-score': 0.2857142857142857,
#   'support': 5.0},
#  'paenibacillus_sp._fsl_h7-0357': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'paenibacillus_sp._fsl_h7-0737': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'paenibacillus_sp._jdr-2': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 3.0},
#  'paenibacillus_sp._rud330': {'precision': 0.42857142857142855,
#   'recall': 1.0,
#   'f1-score': 0.6,
#   'support': 3.0},
#  'paenibacillus_xylanexedens': {'precision': 0.75,
#   'recall': 1.0,
#   'f1-score': 0.8571428571428571,
#   'support': 6.0},
#  'paeniclostridium_sordellii': {'precision': 0.8666666666666667,
#   'recall': 0.8666666666666667,
#   'f1-score': 0.8666666666666667,
#   'support': 15.0},
#  'pandoraea_apista': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'pannonibacter_phragmitetus': {'precision': 0.14285714285714285,
#   'recall': 0.25,
#   'f1-score': 0.18181818181818182,
#   'support': 4.0},
#  'pantoea_agglomerans': {'precision': 0.5,
#   'recall': 0.5,
#   'f1-score': 0.5,
#   'support': 4.0},
#  'pantoea_ananatis': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 4.0},
#  'pantoea_rwandensis': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'pantoea_sp._psnih1': {'precision': 0.3333333333333333,
#   'recall': 1.0,
#   'f1-score': 0.5,
#   'support': 1.0},
#  'pantoea_vagans': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'parabacteroides_distasonis': {'precision': 0.3333333333333333,
#   'recall': 0.25,
#   'f1-score': 0.28571428571428575,
#   'support': 4.0},
#  'parabacteroides_sp._ct06': {'precision': 0.125,
#   'recall': 0.16666666666666666,
#   'f1-score': 0.14285714285714288,
#   'support': 6.0},
#  'paraburkholderia_fungorum': {'precision': 1.0,
#   'recall': 0.3333333333333333,
#   'f1-score': 0.5,
#   'support': 6.0},
#  'paraburkholderia_graminis': {'precision': 0.3333333333333333,
#   'recall': 1.0,
#   'f1-score': 0.5,
#   'support': 1.0},
#  'paraburkholderia_hospita': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'paraburkholderia_phymatum': {'precision': 0.5,
#   'recall': 0.6666666666666666,
#   'f1-score': 0.5714285714285715,
#   'support': 3.0},
#  'paraburkholderia_rhizoxinica': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'paraburkholderia_terrae': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'paracoccus_aminophilus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'paracoccus_denitrificans': {'precision': 1.0,
#   'recall': 0.8571428571428571,
#   'f1-score': 0.923076923076923,
#   'support': 7.0},
#  'paracoccus_mutanolyticus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'parageobacillus_thermoglucosidasius': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'paraglaciecola_psychrophila': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'paraliobacillus_sp._x-1125': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 5.0},
#  'parvimonas_micra': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'pasteurella_multocida': {'precision': 0.9464285714285714,
#   'recall': 1.0,
#   'f1-score': 0.9724770642201834,
#   'support': 53.0},
#  'pasteurellaceae_bacterium_ni1060': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'paucibacter_sp._kctc_42545': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'pectobacterium_atrosepticum': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'pectobacterium_carotovorum': {'precision': 1.0,
#   'recall': 0.3333333333333333,
#   'f1-score': 0.5,
#   'support': 3.0},
#  'pediococcus_acidilactici': {'precision': 0.5,
#   'recall': 1.0,
#   'f1-score': 0.6666666666666666,
#   'support': 2.0},
#  'pediococcus_claussenii': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'pediococcus_damnosus': {'precision': 0.5,
#   'recall': 1.0,
#   'f1-score': 0.6666666666666666,
#   'support': 1.0},
#  'pediococcus_pentosaceus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'pedobacter_cryoconitis': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'pedobacter_ginsengisoli': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 2.0},
#  'pedobacter_steynii': {'precision': 1.0,
#   'recall': 1.0,
#   'f1-score': 1.0,
#   'support': 1.0},
#  'pelobacter_propionicus': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'pelosinus_fermentans': {'precision': 0.5,
#   'recall': 0.5,
#   'f1-score': 0.5,
#   'support': 2.0},
#  'pelosinus_sp._ufo1': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 3.0},
#  'persicobacter_sp._jzb09': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'petrimonas_mucosa': {'precision': 0.0,
#   'recall': 0.0,
#   'f1-score': 0.0,
#   'support': 1.0},
#  'phaeobacter_gallaeciensis': {'precision': 0.3333333333333333,
#   'recall': 0.2,
#   'f1-score': 0.25,
#   'support': 5.0},
#  ...}

# %%
X_test.shape
# Out:
# (131555, 128)

# %%
path_label_issues = "/home/avila/github/panspace-paper/experiments-paper/6mer/07_25_2024-metric_learning/cross-validation/confident-learning/label_issues.npy"

# %%
li = np.load(path_label_issues)

# %%
li.sum()
# Out:
# 215699
