# %%
import json
import pathlib
import numpy as np
import pandas as pd
from cleanlab.outlier import OutOfDistribution   
from cleanlab.rank import find_top_issues

# %%
path="/data/bacteria/File1_full_krakenbracken.txt"
krakenbracken = pd.read_csv(path, sep="\t", usecols=["sample_id","V2","V3","V4","V5","V6","V7"])

# %%
PATH_TRAIN="/data/bacteria/experiments/autoencoders/6mer/27122023-5"
KMER=6
xq = np.load(f"{PATH_TRAIN}/faiss-embeddings/query_embeddings.npy").astype("float32")

# %%
ood = OutOfDistribution()
train_feature_embeddings = np.load(f"{PATH_TRAIN}/faiss-embeddings/embeddings.npy").astype("float32")
test_feature_embeddings = np.load(f"{PATH_TRAIN}/faiss-embeddings/query_embeddings.npy").astype("float32")

# To get outlier scores for train_data using feature matrix train_feature_embeddings
ood_train_feature_scores = ood.fit_score(features=train_feature_embeddings)

# To get outlier scores for additional test_data using feature matrix test_feature_embeddings
ood_test_feature_scores = ood.score(features=test_feature_embeddings)
# Out:
# Fitting OOD estimator based on provided features ...

# %% [markdown]
# ___
# ## Train outliers

# %%
top_train_ood_features_idxs = find_top_issues(quality_scores=ood_train_feature_scores, top=20)

# %%
top_train_ood_features_idxs
# Out:
# array([ 66932,  57040,   1699,  48858,  47255,    622,  75290,  87763,
#         72004,  61354,   3707,  89564,  10104, 106937, 105761,  86574,
#         26259,  87881,  61374,  93858])

# %%
with open(pathlib.Path(PATH_TRAIN).joinpath("faiss-embeddings/id_embeddings.json"),"r") as fp:   
    id_train = json.load(fp)

# %%
id_train = {int(k): v for k,v in id_train.items()}

list_files_outlier_train=[]
for idx in top_train_ood_features_idxs: 
    list_files_outlier_train.append(id_train[idx])

ids_outlier_train = [pathlib.Path(p).stem for p in list_files_outlier_train]

# %%
krakenbracken.query(f"sample_id in {ids_outlier_train}").sort_values("V3")
# Out:
#            sample_id                          V2      V3  \
# 274931  SAMN02199272      Mannheimia haemolytica   2.328
# 285675  SAMN02440684      Mannheimia haemolytica   2.385
# 274631  SAMN02194946     Prochlorococcus marinus   4.714
# 287764  SAMN02585027            Mycoplasma bovis   7.453
# 269019  SAMN00792234    Porphyromonas gingivalis  10.559
# 277874  SAMN02344579    Porphyromonas gingivalis  10.671
# 342328  SAMN03854411    Porphyromonas gingivalis  11.352
# 113025  SAMEA2275256          Campylobacter coli  11.854
# 132747  SAMEA2613127          Campylobacter coli  15.175
# 455482  SAMN06455630           Roseburia hominis  18.801
# 231142  SAMEA4482526    Streptococcus agalactiae  19.912
# 295263  SAMN02786934           Aeromonas veronii  24.137
# 231141  SAMEA4482512    Streptococcus agalactiae  24.348
# 293875  SAMN02745171    Porphyromonas gingivalis  29.131
# 293942  SAMN02745265        Paenibacillus larvae  41.772
# 293771  SAMN02745019  Staphylococcus epidermidis  45.101
# 501464  SAMN07626387     Prochlorococcus marinus  61.644
# 320029  SAMN03360243       Enterococcus faecalis  68.177
# 317830  SAMN03354388       Enterococcus faecalis  84.500
# 294166  SAMN02745618     Vibrio parahaemolyticus  92.494
#
#                                        V4      V5  \
# 274931              Staphylococcus aureus   1.927
# 285675              Staphylococcus aureus   2.264
# 274631                 Campylobacter coli   4.339
# 287764              Mycoplasma bovirhinis   6.194
# 269019  Tannerella sp. oral taxon HOT-286   6.055
# 277874  Tannerella sp. oral taxon HOT-286   5.202
# 342328  Tannerella sp. oral taxon HOT-286   5.504
# 113025      Campylobacter hyointestinalis   8.873
# 132747      Campylobacter hyointestinalis  12.679
# 455482       Faecalibacterium prausnitzii  18.222
# 231142              Actinomyces pacaensis   5.759
# 295263        Arthrobacter sp. PAMC 25486  15.159
# 231141                Rothia mucilaginosa  10.802
# 293875        Porphyromonas crevioricanis   8.483
# 293942         Fusarium pseudograminearum   7.107
# 293771                Cutibacterium acnes  15.062
# 501464       Prochlorococcus sp. MIT 0604  12.118
# 320029          Xanthomonas euvesicatoria  15.579
# 317830          Xanthomonas euvesicatoria   7.844
# 294166              Streptomyces anulatus   1.015
#
#                                    V6      V7
# 274931             Pantoea sp. PSNIH1   1.902
# 285675             Pantoea sp. PSNIH1   1.919
# 274631          Staphylococcus aureus   3.680
# 287764               Mycoplasma cynos   5.787
# 269019  Porphyromonas asaccharolytica   5.470
# 277874  Porphyromonas asaccharolytica   3.753
# 342328  Porphyromonas asaccharolytica   4.805
# 113025           Campylobacter jejuni   8.074
# 132747       Campylobacter iguaniorum   5.850
# 455482              Bacillus subtilis   6.716
# 231142            Veillonella parvula   5.177
# 295263        Cupriavidus taiwanensis   5.823
# 231141            Veillonella parvula   7.200
# 293875    Chryseobacterium gallinarum   4.861
# 293942        Staphylococcus simulans   5.978
# 293771         Friedmanniella luteola   5.118
# 501464       Prochlorococcus sp. RS50  11.119
# 320029    Negativicoccus massiliensis   2.945
# 317830    Negativicoccus massiliensis   1.213
# 294166    Desulfovibrio desulfuricans   0.896

# %% [markdown]
# ## Test outliers

# %%
top_test_ood_features_idxs = find_top_issues(quality_scores=ood_test_feature_scores, top=20)
top_test_ood_features_idxs
# Out:
# array([ 4239,  5999,  9095,  6169, 11595, 11907,  3615, 11827, 11320,
#        12012, 11391,  8642,  2874,  2317,  8993,  9364,  6793,  6326,
#        11103,  9336])

# %%
# find the opposite of outliers
find_top_issues(quality_scores=-ood_test_feature_scores, top=20)
# Out:
# array([  858,  4698,  5734,  2179,   806, 12324,  7569,  5135,  6411,
#        12264,  5917,  5961,   124,  4542,  8554,  5819,  5262,  9121,
#         5838,  8063])

# %%
with open(pathlib.Path(PATH_TRAIN).joinpath("faiss-embeddings/id_query_embeddings.json"),"r") as fp:   
    id_test = json.load(fp)

id_test = {int(k): v for k,v in id_test.items()}

list_files_outlier_test=[]
for idx in top_test_ood_features_idxs: 
    list_files_outlier_test.append(id_test[idx])

ids_test_outlier = [pathlib.Path(p).stem for p in list_files_outlier_test]

# %%
krakenbracken.query(f"sample_id in {ids_test_outlier}").sort_values(by="V3")
# Out:
